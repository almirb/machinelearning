# %%
import pandas as pd
import numpy as np
import matrix_factorization_utilities as mfu
import pickle

# %%
fileSize="ml-100k"

# %%
rating_headers="user id|item id|rating|timestamp".split("|")
rating_df=pd.read_csv(fileSize+"/u.data", delimiter="\t", names=rating_headers)
rating_df.head()
# rating_df["item id"].unique().size #1682
# rating_df["user id"].unique().size #943
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-9f85cb54b17c> in <module>()
#       1 rating_headers="user id|item id|rating|timestamp".split("|")
# ----> 2 rating_df=pd.read_csv(fileSize+"/u.data", delimiter="\t", names=rating_headers)
#       3 rating_df.head()
#       4 # rating_df["item id"].unique().size #1682
#       5 # rating_df["user id"].unique().size #943
#
# ...

# %%
item_headers="movie id| movie title | release date | video release date | IMDb URL | unknown | Action | Adventure | Animation |              Children's | Comedy | Crime | Documentary | Drama | Fantasy |              Film-Noir | Horror | Musical | Mystery | Romance | Sci-Fi |              Thriller | War | Western ".split("|")
items=pd.read_csv(fileSize+"/u.item", encoding="iso-8859-1", delimiter="|", names=item_headers)
# items["movie id"].size #1682

# %%
user_info_headers="user id|age|gender|occupation|zip code".split("|")
user_info=pd.read_csv(fileSize+"/u.user", delimiter="|", names=user_info_headers)
# user_info["user id"].size #943

# %%
rating_pivot_sparse=pd.pivot_table(rating_df,index="user id", values="rating", columns="item id",aggfunc=np.max)
rating_pivot_sparse.iloc[0].size # should be 1682

# %%
U,M=mfu.low_rank_matrix_factorization(rating_pivot_sparse.as_matrix(),num_features=15, regularization_amount=.1)

# %%
pickle.dump(U,open("u_"+fileSize+".dat","wb"))

# %%
pickle.dump(M,open("m_"+fileSize+".dat","wb"))

# %%
# Out:
#       movie id                                       movie title   \
# 639        640    Cook the Thief His Wife & Her Lover, The (1989)
# 799        800                     In the Mouth of Madness (1995)
# 874        875                             She's So Lovely (1997)
# 967        968                      Inspector General, The (1949)
# 897        898                                Postman, The (1997)
# 771        772                                        Kids (1995)
# 1097      1098                      Flirting With Disaster (1996)
# 1257      1258                             Trial and Error (1997)
# 1084      1085                                Carried Away (1996)
# 901        902                           Big Lebowski, The (1998)
# 1064      1065                               Koyaanisqatsi (1983)
# 629        630                             Great Race, The (1965)
# 1008      1009                             Stealing Beauty (1996)
# ...
